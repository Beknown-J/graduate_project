# %% [markdown]
# **注意：1.每一步特征构建或预处理可逆； 2.特征构建后方便组合 3.增删数据要慎重，最终要是可逆；4.将train和test放在一起处理；5.对每一步特征处理的结果进行说明**

# %% [markdown]
# # KaggleRossmanStoreSales

# %% [markdown]
# ## 准备工作

# %%
import pandas as pd
from pandas import Series, DataFrame
import itertools
import numpy as np
from datetime import datetime, date
from IPython.display import display
from datetime import datetime
import matplotlib.pyplot as plt
import xgboost as xgb
import math

# %matplotlib inline

# %% [markdown]
# ### 评价指标
#
# 选择RMSPE作为评价指标，定义为：
#
# $RMSPE=\sqrt{\frac{1}{n}\sum_{i=1}^N(\frac{y_i-\hat{y_i}}{y_i})^2} $

# %%
# 构建评价指标
def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w

def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe

# xgboost中的rmpse
def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %% [markdown]
# ### 读取数据

# %%
train = pd.read_csv('./参考资料/kaggle-rossman-store-sales/input/train.csv', dtype = {'StateHoliday':str}, parse_dates=['Date'], date_parser=(lambda dt: pd.to_datetime(dt, format='%Y-%m-%d')))
store = pd.read_csv('./参考资料/kaggle-rossman-store-sales/input/store.csv', dtype = {'PromoInterval':str, 'CompetitionOpenSinceYear':str, 'CompetitionOpenSinceMonth':str})
test = pd.read_csv('./参考资料/kaggle-rossman-store-sales/input/test.csv', dtype = {'PromoInterval':str, 'CompetitionOpenSinceYear':str, 'CompetitionOpenSinceMonth':str}, parse_dates=['Date'],date_parser=(lambda dt: pd.to_datetime(dt, format='%Y-%m-%d')))

# %% [markdown]
# ## 特征工程

# %% [markdown]
# **1.将train和test合并**
#
# 方便对两个数据集进行同样的处理，同时可以避免一些错误。比如：单独对test数据集进行onehot处理时时少两列：'StateHoliday_b', 'StateHoliday_c'

# %%
train['Insample'] = 1
test['Insample'] = 0

# %%
# 合并train和test
all_data = pd.concat([train, test])

# %% [markdown]
# > Attention：all_data新增特征：“Insample”；通过该字段来区分train和test

# %% [markdown]
# **2.删除明显异常的数据**
#
# 删除Open = 1, Sales =0的数据

# %%
sub_all_data = all_data.loc[~((all_data['Open'] == 1) & (all_data['Sales'] == 0))]

# %%
print("删除之前行数为：", len(all_data))
print("删除之后行数为：", len(sub_all_data))
# Out:
# 删除之前行数为： 1058297
# 删除之后行数为： 1058243

# %% [markdown]
# > Attention:处理后数据集为sub_all_data，一共删除了54行数据。说明异常数据点很少，属于正常范围

# %% [markdown]
# **3.对类别特征进行one-hot处理**
#
# train进行该处理的字段有：'StateHoliday'

# %%
display(sub_all_data.StateHoliday.unique())
# Out:
# array(['0', 'a', 'b', 'c'], dtype=object)

# %%
sub_all_data = pd.get_dummies(sub_all_data, columns=['StateHoliday'])

# %% [markdown]
# > Attention：sub_all_data新增特征：'StateHoliday_0', 'StateHoliday_a', 'StateHoliday_b', 'StateHoliday_c'

# %% [markdown]
# **4.根据Date构造特征**

# %%
Date = 'Date'

sub_all_data['Day'] = pd.Index(sub_all_data[Date]).day
sub_all_data['Week'] = pd.Index(sub_all_data[Date]).week
sub_all_data['Month'] = pd.Index(sub_all_data[Date]).month
sub_all_data['Year'] = pd.Index(sub_all_data[Date]).year
sub_all_data['DayOfYear'] = pd.Index(sub_all_data[Date]).dayofyear

# %% [markdown]
# > Attention: sub_all_data新增特征：'Day', 'Week', 'Month', 'Year', 'DayOfYear'

# %% [markdown]
# **5.把Date日期转化为数值作为特征**

# %%
sub_all_data['DateInt'] = sub_all_data['Date'].astype(np.int64)

# %% [markdown]
# > Attention: sub_all_data新增特征：'DateInt'

# %% [markdown]
# **6.标记sub_all_data中可能的异常值**

# %%
# 值得学习，删除了偏差大的Saless数据，再理解一下
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        #将points变为array
        points = points[:,None]
    # 取中位数
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
for i in sub_all_data['Store'].unique():
    sub_all_data.loc[(sub_all_data['Insample'] == 1) & (sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1), 'Outlier'] = \
        mad_based_outlier(sub_all_data.loc[(sub_all_data['Insample'] == 1) & (sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1)]['Sales'], 3)

# %%
stores_to_check = [105,163,172,364,378,523,589,663,676,681,700,708,730,764,837,845,861,882,969,986]

plt.rcParams["figure.figsize"] = [20,len(stores_to_check)*5]

j = 1
for i in stores_to_check:
    
    # Normal sales
    X1 = sub_all_data.loc[(sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == False)]
    y1 = sub_all_data.loc[(sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == False)]['Sales']

    # Outliers
    X2 = sub_all_data.loc[(sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == True)]
    y2 = sub_all_data.loc[(sub_all_data['Store'] == i) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == True)]['Sales']

    # Xt = df.loc[(df['Store'] == i)]
    
    plt.subplot(10,5,j)
    plt.plot(X1['Date'], y1, '-')
    plt.plot(X2['Date'], y2, 'r.')
    plt.title(i)
    plt.axis('off')
    j = j + 1

# %% [markdown]
# 可以从上图中看出，红色点的确是异常值点
#
# > Attention: sub_all_data新增特征：'Outlier'

# %% [markdown]
# **7.增加关于store的一些特征**

# %%
store_onehot = pd.get_dummies(store, columns=['StoreType'])
Assortment_mapping = {'a':1, 'b': 2, 'c':3}
store_onehot['Assortment_onehot'] = store_onehot['Assortment'].map(Assortment_mapping)

# %%
# 得到商铺历史销售总额，历史顾客数量，历史开业天数
store_sales = sub_all_data['Sales'].groupby(sub_all_data['Store']).sum()
store_customers = sub_all_data['Customers'].groupby(sub_all_data['Store']).sum()
store_opendays = sub_all_data['Open'].groupby(sub_all_data['Store']).count()

# 增加了店铺的三个特征
EachDay_store_sales = store_sales/store_opendays
EachDay_store_customers = store_customers/store_opendays
EachCustomer_cosume = EachDay_store_sales/EachDay_store_customers

# %%
store_onehot = pd.merge(store_onehot, EachDay_store_sales.reset_index(name='SalesPerDay'), how='left', on=['Store'])
store_onehot = pd.merge(store_onehot, EachDay_store_customers.reset_index(name='CustomersPerDay'), how='left', on=['Store'])
store_onehot = pd.merge(store_onehot, EachCustomer_cosume.reset_index(name='SalesPerCustomersPerDay'), how='left', on=['Store'])

# %%
store_features = ['Store', 'Assortment_onehot','StoreType_a','StoreType_b', 'StoreType_c', 'StoreType_d', 'SalesPerDay', 'CustomersPerDay', 'SalesPerCustomersPerDay']
sub_all_data = pd.merge(sub_all_data, store_onehot[store_features], how='left', on=['Store'])

# %% [markdown]
# > store_onehot新增特征：'Assortment_onehot','StoreType_a','StoreType_b', 'StoreType_c', 'StoreType_d', 'SalesPerDay',
# 'CustomersPerDay', 'SalesPerCustomersPerDay'
#
# > sub_all_data与store_onehot合并

# %% [markdown]
# **8.对Sales进行log处理**

# %%
sub_all_data['SalesLog'] = np.log(sub_all_data['Sales'] + 1)

# %% [markdown]
# **9.获得竞争对手开业时间**

# %%
def get_CompteOpenDate(data):
    
    is_na = list(data.loc[['CompetitionOpenSinceYear', 'CompetitionOpenSinceMonth']].isnull())
    if True in is_na:
        return(0)
    else:
        opendate = data['CompetitionOpenSinceYear']+'-' + data['CompetitionOpenSinceMonth']+'-01'
    
        data['CompeteOpenDate'] = opendate#pd.to_datetime(opendate, format="%Y-%m-%d")
        #data['CompeteOpenDate'] = datetime.strptime(opendate, "%Y-%m-%d")
        return(data)

# %%
store_onehot = store_onehot.apply(get_CompteOpenDate, axis=1)

# %%
store_features2 = ['Store', 'CompeteOpenDate']
sub_all_data = pd.merge(sub_all_data, store_onehot[store_features2], how='left', on=['Store'])

# %% [markdown]
# > Attention：store_onehot增加特征：'CompeteOpenDate'

# %% [markdown]
# **10.CompeteOpen竞争对手是否开门**
#
# 增加字段 CompeteOpen，判断竞争对手是否营业。通过Date >= CompetitionOpenDate和Open两个一起判断。也就是说首先判断CompetitionOpenDate是否早于Date，如果是，与该日期本店铺的Open一致，如果不是则为未开门0。

# %%
# 首先要做的是合并train_all_onehot和store_onehot
sub_all_data['CompeteOpenDate'] = pd.to_datetime(sub_all_data['CompeteOpenDate'])

# %%
def judge_compete_open(date, compete_date, opened):
    if date > compete_date and opened == 1:
        return(1)
    else:
        return(0)

# %%
sub_all_data['CompeteOpen'] = sub_all_data.apply(lambda x: judge_compete_open(x.Date, x.CompeteOpenDate, x.Open), axis=1)

# %% [markdown]
# >Attention：sub_all_data增加特征'CompeteOpen'

# %% [markdown]
# **11.Promo2Active商品当天是否有特殊促销活动（Promo2）**
#
# 判断当天是否有Promo2的促销活动。

# %%
def judge_promot2(date, p2SinceWeek, p2SinceYear, p2Interval, promot2):
    date_year = date.year
    date_mon = date.month
    date_week = date.week
    month_abbr = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    date_mon_abbr = month_abbr[date_mon-1]
    judge = (date_year > p2SinceYear or (date_year == p2SinceYear and date_week > p2SinceWeek)) and date_mon_abbr in p2Interval
        
    return(promot2*judge)

# %%
store_features3 = ['Store', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'Promo2']
sub_all_data = pd.merge(sub_all_data, store_onehot[store_features3], how='left', on=['Store'])

# %%
sub_all_data['Promo2Active'] = sub_all_data.apply(lambda x: judge_promot2(x.Date, x.Promo2SinceWeek, x.Promo2SinceYear, x.PromoInterval, x.Promo2), axis=1)

# %% [markdown]
# > Attention：sub_all_data增加特征'Promo2Active'

# %%
sub_all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1058243 entries, 0 to 1058242
# Data columns (total 37 columns):
# Customers                  1017155 non-null float64
# Date                       1058243 non-null datetime64[ns]
# DayOfWeek                  1058243 non-null int64
# Id                         41088 non-null float64
# Insample                   1058243 non-null int64
# Open                       1058232 non-null float64
# Promo                      1058243 non-null int64
# Sales                      1017155 non-null float64
# SchoolHoliday              1058243 non-null int64
# Store                      1058243 non-null int64
# StateHoliday_0             1058243 non-null uint8
# StateHoliday_a             1058243 non-null uint8
# StateHoliday_b             1058243 non-null uint8
# StateHoliday_c             1058243 non-null uint8
# Day                        1058243 non-null int64
# Week                       1058243 non-null int64
# Month                      1058243 non-null int64
# Year                       1058243 non-null int64
# DayOfYear                  1058243 non-null int64
# DateInt                    1058243 non-null int64
# Outlier                    844338 non-null object
# Assortment_onehot          1058243 non-null int64
# StoreType_a                1058243 non-null uint8
# StoreType_b                1058243 non-null uint8
# StoreType_c                1058243 non-null uint8
# StoreType_d                1058243 non-null uint8
# SalesPerDay                1058243 non-null float64
# CustomersPerDay            1058243 non-null float64
# SalesPerCustomersPerDay    1058243 non-null float64
# SalesLog                   1017155 non-null float64
# CompeteOpenDate            719698 non-null datetime64[ns]
# CompeteOpen                1058243 non-null int64
# Promo2SinceWeek            339134 non-null float64
# Promo2SinceYear            339134 non-null float64
# PromoInterval              339134 non-null object
# Promo2                     719698 non-null float64
# Promo2Active               719698 non-null float64
# dtypes: datetime64[ns](2), float64(12), int64(13), object(2), uint8(8)
# memory usage: 250.3+ MB

# %%
sub_all_data.to_pickle('sub_all_data_version3.pkl')

# %%
sub_all_data = pd.read_pickle('sub_all_data_version3.pkl')

# %% [markdown]
# ## 选择特征

# %%
features = sub_all_data.columns.values
features
# Out:
# array(['Customers', 'Date', 'DayOfWeek', 'Id', 'Insample', 'Open', 'Promo',
#        'Sales', 'SchoolHoliday', 'Store', 'StateHoliday_0',
#        'StateHoliday_a', 'StateHoliday_b', 'StateHoliday_c', 'Day', 'Week',
#        'Month', 'Year', 'DayOfYear', 'DateInt', 'Outlier',
#        'Assortment_onehot', 'StoreType_a', 'StoreType_b', 'StoreType_c',
#        'StoreType_d', 'SalesPerDay', 'CustomersPerDay',
#        'SalesPerCustomersPerDay', 'SalesLog', 'CompeteOpenDate',
#        'CompeteOpen', 'Promo2SinceWeek', 'Promo2SinceYear',
#        'PromoInterval', 'Promo2', 'Promo2Active'], dtype=object)

# %% [markdown]
# ### 方案一

# %%
features_x = ['DayOfWeek', 'Open', 'Promo','SchoolHoliday', 'Store', 'StateHoliday_0','StateHoliday_a', 'StateHoliday_b',
              'StateHoliday_c', 'Day', 'Week','Month', 'Year', 'DayOfYear', 
              'Assortment_onehot', 'StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d', 'SalesPerDay',
              'CustomersPerDay','SalesPerCustomersPerDay']
features_y = ['SalesLog']

# %% [markdown]
# ### 方案二

# %%
features_x = ['DayOfWeek', 'Open', 'Promo','SchoolHoliday', 'Store', 'StateHoliday_0','StateHoliday_a', 'StateHoliday_b',
              'StateHoliday_c', 'Day', 'Week','Month', 'Year', 'DayOfYear', 
              'Assortment_onehot', 'StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d', 'SalesPerDay',
              'CustomersPerDay','SalesPerCustomersPerDay', 'CompeteOpen', 'Promo2Active']
features_y = ['SalesLog']

# %% [markdown]
# ## 数据分割

# %% [markdown]
# ### 随机分割

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /Users/mingj/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
seed = 12

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(sub_all_data.loc[(sub_all_data['Insample'] == 1) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == False)][features_x],
                                                    sub_all_data.loc[(sub_all_data['Insample'] == 1) & (sub_all_data['Open'] == 1) & (sub_all_data['Outlier'] == False)][features_y],
                                                    test_size=0.1, random_state=seed)

# %% [markdown]
# ### 按时间分割

# %%
# 这里使用位运算，可以得到两个条件的子集
all_train = sub_all_data[sub_all_data.Date < datetime.strptime('2015-06-20', '%Y-%m-%d') ]
all_valid = sub_all_data[sub_all_data.Date >= datetime.strptime('2015-06-20', '%Y-%m-%d')]

X_train_time = all_train.loc[(all_train['Insample'] == 1)& (all_train['Open'] == 1)&(all_train['Outlier'] == False)][features_x]
Y_train_time = all_train.loc[(all_train['Insample'] == 1)& (all_train['Open'] == 1)&(all_train['Outlier'] == False)][features_y]

X_valid_time = all_valid.loc[(all_valid['Insample'] == 1)& (all_train['Open'] == 1)&(all_valid['Outlier'] == False)][features_x]
Y_valid_time = all_valid.loc[(all_valid['Insample'] == 1)& (all_train['Open'] == 1)&(all_valid['Outlier'] == False)][features_y]

# %% [markdown]
# ## 训练
#
# **方案二+随机分割**

# %%
dtrain = xgb.DMatrix(X_train, Y_train)
dvalid = xgb.DMatrix(X_valid, Y_valid)

# %%
num_round = 10000
evallist = [(dtrain, 'train'), (dvalid, 'valid')]

# %%
param = {'bst:max_depth':12,
         'bst:eta':0.0095,
         'subsample':0.8,
         'colsample_bytree':0.7,
         'silent':1, 
         'objective':'reg:linear',
         'nthread':6,
         'seed':seed}

plst = param.items()

# %%
X_train.columns
# Out:
# Index(['DayOfWeek', 'Open', 'Promo', 'SchoolHoliday', 'Store',
#        'StateHoliday_0', 'StateHoliday_a', 'StateHoliday_b', 'StateHoliday_c',
#        'Day', 'Week', 'Month', 'Year', 'DayOfYear', 'Assortment_onehot',
#        'StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d',
#        'SalesPerDay', 'CustomersPerDay', 'SalesPerCustomersPerDay',
#        'CompeteOpen', 'Promo2Active'],
#       dtype='object')

# %%
bst = xgb.train(plst, dtrain, num_round, evallist, feval=rmspe_xg, verbose_eval=10, early_stopping_rounds=100)
# Out:
# [0]	train-rmse:5.78416	valid-rmse:5.78425	train-rmspe:0.996866	valid-rmspe:0.996869
# Multiple eval metrics have been passed: 'valid-rmspe' will be used for early stopping.
#
# Will train until valid-rmspe hasn't improved in 100 rounds.
# [10]	train-rmse:0.235309	valid-rmse:0.234851	train-rmspe:0.240895	valid-rmspe:0.212419
# [20]	train-rmse:0.15682	valid-rmse:0.15627	train-rmspe:0.219096	valid-rmspe:0.173292
# [30]	train-rmse:0.149824	valid-rmse:0.149208	train-rmspe:0.210995	valid-rmspe:0.164272
# [40]	train-rmse:0.146262	valid-rmse:0.145773	train-rmspe:0.206876	valid-rmspe:0.159898
# [50]	train-rmse:0.140312	valid-rmse:0.140033	train-rmspe:0.197038	valid-rmspe:0.152525
# [60]	train-rmse:0.136258	valid-rmse:0.135975	train-rmspe:0.191735	valid-rmspe:0.14736
# [70]	train-rmse:0.133689	valid-rmse:0.133613	train-rmspe:0.190999	valid-rmspe:0.144523
# [80]	train-rmse:0.131206	valid-rmse:0.131241	train-rmspe:0.188709	valid-rmspe:0.141604
# [90]	train-rmse:0.128823	valid-rmse:0.128965	train-rmspe:0.186576	valid-rmspe:0.138917
# [100]	train-rmse:0.126681	valid-rmse:0.126812	train-rmspe:0.184598	valid-rmspe:0.136338
# [110]	train-rmse:0.124893	valid-rmse:0.125047	train-rmspe:0.180954	valid-rmspe:0.134306
# [120]	train-rmse:0.123393	valid-rmse:0.123586	train-rmspe:0.179385	valid-rmspe:0.132272
# [130]	train-rmse:0.121062	valid-rmse:0.121253	train-rmspe:0.176697	valid-rmspe:0.129658
# [140]	train-rmse:0.119911	valid-rmse:0.120166	train-rmspe:0.175715	valid-rmspe:0.128439
# [150]	train-rmse:0.118219	valid-rmse:0.118576	train-rmspe:0.174427	valid-rmspe:0.126668
# [160]	train-rmse:0.117025	valid-rmse:0.117452	train-rmspe:0.17346	valid-rmspe:0.125375
# [170]	train-rmse:0.115759	valid-rmse:0.116256	train-rmspe:0.172099	valid-rmspe:0.124072
# [180]	train-rmse:0.114378	valid-rmse:0.114928	train-rmspe:0.170788	valid-rmspe:0.122672
# [190]	train-rmse:0.11342	valid-rmse:0.114045	train-rmspe:0.170421	valid-rmspe:0.121738
# [200]	train-rmse:0.112732	valid-rmse:0.113429	train-rmspe:0.169839	valid-rmspe:0.121071
# [210]	train-rmse:0.111666	valid-rmse:0.112496	train-rmspe:0.168958	valid-rmspe:0.120055
# [220]	train-rmse:0.110689	valid-rmse:0.111599	train-rmspe:0.168039	valid-rmspe:0.119106
# [230]	train-rmse:0.109844	valid-rmse:0.11084	train-rmspe:0.16691	valid-rmspe:0.118297
# [3380]	train-rmse:0.073263	valid-rmse:0.086558	train-rmspe:0.077587	valid-rmspe:0.092838
# [3390]	train-rmse:0.073233	valid-rmse:0.086548	train-rmspe:0.077538	valid-rmspe:0.092826
# [3400]	train-rmse:0.073203	valid-rmse:0.086541	train-rmspe:0.077507	valid-rmspe:0.092822
# [3410]	train-rmse:0.07318	valid-rmse:0.08654	train-rmspe:0.077479	valid-rmspe:0.092835
# [3420]	train-rmse:0.073144	valid-rmse:0.086535	train-rmspe:0.077429	valid-rmspe:0.09282
# [3430]	train-rmse:0.073111	valid-rmse:0.086518	train-rmspe:0.077396	valid-rmspe:0.092807
# [3440]	train-rmse:0.073083	valid-rmse:0.086517	train-rmspe:0.077351	valid-rmspe:0.092786
# [3450]	train-rmse:0.073056	valid-rmse:0.086519	train-rmspe:0.077326	valid-rmspe:0.092793
# [3460]	train-rmse:0.073025	valid-rmse:0.086524	train-rmspe:0.077278	valid-rmspe:0.092854
# [3470]	train-rmse:0.072991	valid-rmse:0.086524	train-rmspe:0.077229	valid-rmspe:0.092839
# [3480]	train-rmse:0.072964	valid-rmse:0.086525	train-rmspe:0.077488	valid-rmspe:0.09284
# [3490]	train-rmse:0.072928	valid-rmse:0.086515	train-rmspe:0.077432	valid-rmspe:0.09283
# [3500]	train-rmse:0.072903	valid-rmse:0.086504	train-rmspe:0.077402	valid-rmspe:0.092821
# [3510]	train-rmse:0.072873	valid-rmse:0.086503	train-rmspe:0.077376	valid-rmspe:0.09283
# [3520]	train-rmse:0.072845	valid-rmse:0.086508	train-rmspe:0.077345	valid-rmspe:0.092891
# [3530]	train-rmse:0.072816	valid-rmse:0.086497	train-rmspe:0.077312	valid-rmspe:0.09288
# [3540]	train-rmse:0.072788	valid-rmse:0.086495	train-rmspe:0.077258	valid-rmspe:0.092892
# Stopping. Best iteration:
# [3440]	train-rmse:0.073083	valid-rmse:0.086517	train-rmspe:0.077351	valid-rmspe:0.092786

# %%
bst.save_model('xgb_version3_方案二+随机分割.model')

# %%
xgb.plot_importance(bst)

# %% [markdown]
# ## 预测

# %% [markdown]
# ### 在valid数据集上预测结果

# %%
bst = xgb.Booster(model_file="xgb_version3_方案二+随机分割.model")

# %%
# 看一下在valid上的预测效果
pred_valid = bst.predict(dvalid, output_margin = True)
# real_pred_valid = revive_sales(data = X_valid, pred = pred_valid)
real_pred_valid = (np.exp(pred_valid) - 1) #* 0.985
acc = rmspe(real_pred_valid, Y_valid.values)
print("RMSPE准确率为：", acc)

# %% [markdown]
# ### test数据集预测结果提交kaggle

# %%
X_submit = sub_all_data.loc[sub_all_data['Insample'] == 0]
dsubmit = xgb.DMatrix(X_submit[features_x])

ypred_bst = bst.predict(dsubmit)

df_ypred = X_submit['Id'].reset_index()
del df_ypred['index']
df_ypred['Id'] = df_ypred['Id'].astype('int')

# Scale back the sales a bit
df_ypred['Sales'] = (np.exp(ypred_bst) - 1) # * 0.985

df_ypred.sort_values('Id', inplace=True)
df_ypred[['Id', 'Sales']].to_csv('./结果提交/submission_version3.csv', index=False)

# %% [markdown]
# -------- 测试 ---------
